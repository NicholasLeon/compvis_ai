# %% [markdown]
# # YOLO11 Training Utilities (Show results.csv)

# %%
import torch
print('GPU Available:', torch.cuda.is_available())
print('GPU Name:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None')
# Out:
# GPU Available: True
# GPU Name: NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %%
# Test dataset loading
from ultralytics import YOLO
model = YOLO('yolo11n.pt')
# Replace with your dataset path
dataset_path = 'data.yaml'
print('Dataset OK if no error appears.')
# Out:
# Dataset OK if no error appears.

# %%
# Test results.csv
import pandas as pd
results = pd.read_csv('runs/detect/train3/results.csv')
results.head()
# Out:
#    epoch      time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1   63.3683         0.90751         1.73214         0.97904
# 1      2  102.3330         0.93831         1.08509         0.98508
# 2      3  141.6670         0.95157         0.90377         0.99292
# 3      4  181.9860         0.91155         0.77322         0.97240
# 4      5  221.6860         0.89885         0.73226         0.96424
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.92731            0.89298           0.95611
# 1               0.88486            0.83946           0.93281
# 2               0.84817            0.89681           0.93003
# 3               0.96205            0.93261           0.97031
# 4               0.93419            0.94950           0.96856
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0              0.67222       0.91699       1.16122       0.93018  0.000664
# 1              0.65794       0.96764       0.90267       0.96633  0.001314
# 2              0.68549       0.90809       0.95406       0.93800  0.001948
# 3              0.68634       0.90667       0.72033       0.92476  0.001926
# 4              0.72402       0.85172       0.60656       0.90971  0.001901
#
#      lr/pg1    lr/pg2
# 0  0.000664  0.000664
# 1  0.001314  0.001314
# 2  0.001948  0.001948
# 3  0.001926  0.001926
# 4  0.001901  0.001901
