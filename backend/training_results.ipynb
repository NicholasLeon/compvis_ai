# %% [markdown]
# # YOLO11 Training Utilities

# %%
import torch
print('GPU Available:', torch.cuda.is_available())
print('GPU Name:', torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None')
# Out:
# GPU Available: True
# GPU Name: NVIDIA GeForce RTX 3050 6GB Laptop GPU

# %%
# Test dataset loading
from ultralytics import YOLO
model = YOLO('yolo11n.pt')
# Replace with your dataset path
dataset_path = 'data.yaml'
print('Dataset OK if no error appears.')
# Out:
# Dataset OK if no error appears.

# %%
# Test results.csv
import pandas as pd
results = pd.read_csv('runs/detect/train3/results.csv')
results.head()
# Out:
#    epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1  35.5905         1.50142         2.91579         1.11040
# 1      2  51.0341         1.33875         1.61220         0.98054
# 2      3  66.4700         1.31836         1.37539         0.98459
# 3      4  82.1069         1.30232         1.18040         0.99058
# 4      5  97.4357         1.25200         1.06943         0.99075
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.00437            0.73184           0.00649
# 1               0.84272            0.14969           0.77897
# 2               0.95745            0.91620           0.97299
# 3               0.96459            0.91310           0.96684
# 4               0.94558            0.91061           0.95254
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0              0.00278       1.30886       3.78765       0.98291  0.000653
# 1              0.40645       1.31462       2.78922       1.00847  0.001294
# 2              0.63814       1.14437       1.21615       0.99384  0.001908
# 3              0.65476       1.11438       0.93234       0.97559  0.001881
# 4              0.58618       1.21208       0.80312       0.98058  0.001842
#
#      lr/pg1    lr/pg2
# 0  0.000653  0.000653
# 1  0.001294  0.001294
# 2  0.001908  0.001908
# 3  0.001881  0.001881
# 4  0.001842  0.001842
